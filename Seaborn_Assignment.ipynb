# %% [markdown]
# ## Que 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.

# %% [markdown]
# Here are five plots you can create using the Seaborn library, along with their uses:
#
# * 1 Line Plot: This plot is ideal for visualizing trends over time. It is often used to represent continuous data, such as time-series analysis.
#
# * 2 Bar Plot: A bar plot is used to compare categorical data. It helps to display the relationship between a categorical variable and a numerical variable.
#
# * 3 Scatter Plot: This plot is useful for identifying relationships or correlations between two numerical variables. It’s a great way to visualize clusters or patterns in data.
#
# * 4 Box Plot (or Whisker Plot): A box plot provides insights into the distribution of data by showing medians, quartiles, and potential outliers.
#
# * 5 Heatmap: This plot is used to visualize data in a matrix form, showing the relationship between two variables using color intensities.
#
# These plots are widely used in data visualization to uncover patterns, trends, and insights effectivel

# %% [markdown]
# ## Que 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x = "timepoint" and y = "signal" for different events and regions.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the fmri dataset
data = sns.load_dataset("fmri")

# Create a line plot
sns.lineplot(data=data, x="timepoint", y="signal", hue="event", style="region")
plt.title("FMRI Line Plot: Timepoint vs Signal for Events and Regions")
plt.show()

# %% [markdown]
# ## Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x = 'pclass', y = 'age' and y = 'fare'.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
data = sns.load_dataset("titanic")

# Plot 1: Box plot for pclass vs age
plt.figure(figsize=(10, 5))
sns.boxplot(x="pclass", y="age", data=data)
plt.title("Box Plot: Passenger Class vs Age")
plt.show()

# Plot 2: Box plot for pclass vs fare
plt.figure(figsize=(10, 5))
sns.boxplot(x="pclass", y="fare", data=data)
plt.title("Box Plot: Passenger Class vs Fare")
plt.show()

# %% [markdown]
# ## Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue parameter for the 'cut' column of the diamonds dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the diamonds dataset
data = sns.load_dataset("diamonds")

# Create a histogram
sns.histplot(data=data, x="price", hue="cut", kde=True, palette="Set2")
plt.title("Histogram of Diamond Prices by Cut")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # Que 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column of the iris dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the iris dataset
data = sns.load_dataset("iris")

# Create a pair plot
sns.pairplot(data=data, hue="species", palette="Set1")
plt.suptitle("Pair Plot of Iris Dataset", y=1.02)
plt.show()

# %% [markdown]
# # Que 6: Use the "flights" dataset from seaborn to plot a heatmap.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the flights dataset
data = sns.load_dataset("flights")

# Correctly pivot the dataset
pivot_data = data.pivot(index="month", columns="year", values="passengers")

# Create the heatmap
sns.heatmap(pivot_data, annot=True, fmt="d", cmap="coolwarm")
plt.title("Heatmap of Flights Data")
plt.show()
